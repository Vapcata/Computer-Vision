# %% [markdown]
# # Preparation of milestone three
#
# Today we will start preparing the third milestone. The third milestone is to train an object detector to recognize cells. To successfully complete the milestone, you will have to complete the following sub-tasks:
# - Initialize a pytorch object detector. I'd suggest to choose a RetinaNet or FCOS detection model. More Information can be found [here](https://pytorch.org/vision/stable/models.html#object-detection-instance-segmentation-and-person-keypoint-detection). Since we do not have endless compute power available, we will use a pre-trained backbone and only train the detection and classification heads of our object detector. So you will have to finde a way to **freeze** the backbone of your detector.
# - You will have to write a [training and validation/test](https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html) loop to train your detector. Make sure you measure the convergence of the training by monitoring a detection metric like the [mAP](https://torchmetrics.readthedocs.io/en/stable/detection/mean_average_precision.html). Also, you will have to find a way to select the best model during training based on some metric. The detection models of torchvision already return a loss when they are in evaluation mode, so you don't need to configure your own one.
# - Train your model for a few epochs. If you do not have a gpu available, I suggest using colab, as training the model on the cpu is extremely slow. You will also need to pass your dataset to a dataloader to take advantage of multithreading and automatic batching.
# - At the end, you will have to save the **state_dict** of your trained object detector, to be able to reuse it later.
#
# Please use a jupyter notebook for coding your training/testing pipeline. In the end, you will have to submit that jupiter notebook at moodle. Please do not try to upload any model weights.

# %% [markdown]
# # If you run the notebook in colab, you have to mount the google drive with the images. Proceed as follows:
#
# - **First**: Open the following **[link](https://drive.google.com/drive/folders/18P74V8kli6qDZtGBLN-tPrJFu3O2NPEK?usp=sharing)** in a new tab.
# - **Second**: Add a link to your google Drive.
# Example: [Link](https://drive.google.com/file/d/1IcFGGIoktPkDj9-4j5IQ3evInn0c2aq-/view?usp=sharing)
# - **Third**: Run the line of code below
# - **Fourth**: Grant Google access to your Drive

# %%
from google.colab import drive

# (https://drive.google.com/drive/folders/18P74V8kli6qDZtGBLN-tPrJFu3O2NPEK?usp=sharing)
# # path to the link you created
path_to_slides = '/content/gdrive/MyDrive/AgNORs/'
# # mount the data
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
import torch
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torch.optim as optim
# !pip install torchmetrics -y
import torchmetrics
# Out:
# /Users/alexandervaptsarov/Library/jupyterlab-desktop/envs/cv/lib/python3.12/site-packages/threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)

# %% [markdown]
# # 1. Create a Custom Dataset Class for training your object detection model
#
# In the last milestone, you learned about custom data sets in pytorch. In this milestone, we are going to train an object detection model, for which we also need a custom dataset. Last time, the dataset returned only one cell each time the getitem method was called. This time, we need to return a larger portion of the image to feed the object detector. Since there may be more than one cell in the image, you will also need to return the labels and bounding box information for each cell in the respective crop. Think about how to deal with cells that are at the edges of the crop and therefore not completely visible. Also consider what to do if there is no annotation on the image.
#
# Your dataset must have the following characteristics:
#
# 1. Since you are going to randomly sample the crops from the images, you need a parameter that defines how many crops will be sampled in an epoch (num_samples).
# 2. You need to define the size of the patches that will be sampled from the images during training (crop_size).
# 3. Since we do not have many images available, we will need image augmentation. Geometric augmentations are a bit tricky for object detection, because you always have to transform the bounding boxes as well. The [albumentations](https://albumentations.ai/docs/getting_started/bounding_boxes_augmentation/) module solves this quite nicely, so I suggest using it for the augmentations in this task.
# 4. Have a look at pytorch and torchmetrics to see in which format the metrics as well as the models expect the images and tragets.
# 5. Although we do not actively detect a background class, the label "0" is always reserved for the background class. Therefore, your dataset must return the label "1" for each cell.

# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset
from PIL import Image

class CustomDatasetClass(Dataset):
    def __init__(self, annotations_file, img_dir, num_samples, crop_size, transform=None):
        """
        Custom Dataset Class for Object Detection Tasks.

        Args:
        - annotations_file (str): Path to the CSV file containing annotations.
        - img_dir (str): Directory containing images.
        - num_samples (int): Number of samples in the dataset.
        - crop_size (tuple): Size of the cropped image (height, width).
        - transform (callable, optional): Optional transformations to be applied to the image.
        """
        self.img_labels = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.num_samples = num_samples
        self.crop_size = crop_size
        self.transform = transform

    def __len__(self):
        return self.num_samples

    def __getitem__(self, sample_index):
        img_idx = sample_index % len(self.img_labels)
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[img_idx, 0])

        try:
            img = Image.open(img_path).convert("RGB")
        except Exception as e:
            print(f"Error loading image at index {sample_index}: {e}")
            return None

        annotations = self.img_labels[self.img_labels.iloc[:, 0] == self.img_labels.iloc[img_idx, 0]]

        width, height = img.size
        crop_x = torch.randint(0, width - self.crop_size[1] + 1, (1,)).item()
        crop_y = torch.randint(0, height - self.crop_size[0] + 1, (1,)).item()
        img = img.crop((crop_x, crop_y, crop_x + self.crop_size[1], crop_y + self.crop_size[0]))

        # Bounding boxes for the crop
        bboxes = []
        labels = []
        for _, row in annotations.iterrows():
            x_min, y_min, x_max, y_max = row[3], row[4], row[1], row[2]
            if x_min >= crop_x and x_max <= crop_x + self.crop_size[1] and y_min >= crop_y and y_max <= crop_y + self.crop_size[0]:
                bboxes.append([x_min - crop_x, y_min - crop_y, x_max - crop_x, y_max - crop_y])
                labels.append(1)  # Label 1 for cells

        if len(bboxes) == 0:
            bboxes = [[0, 0, 0, 0]]  # Default if no bbox in crop
            labels = [0]  # Background class

        if self.transform:
            try:
                img = self.transform(img)
            except Exception as e:
                print(f"Error applying transform to image at index {sample_index}: {e}")
                return None

        img = np.array(img)
        img = torch.tensor(img).permute(2, 0, 1).float() / 255.0
        target = {
            'boxes': torch.tensor(bboxes, dtype=torch.float32),
            'labels': torch.tensor(labels, dtype=torch.int64)
        }

        return img, target, labels

# %% [markdown]
# # 2. Initializing the model
#
# Initialize a pre-trained object detector from torchvision. Since you need to detect cells, you need two classes (a background class and a "cell" class). Some detection models like FasterRCNN or Retinanet use anchor boxes. If you choose to work with one of these models, you will need to select anchorboxes with a size that matches the size of the detection targets.

# %%
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn, retinanet_resnet50_fpn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader

weights = torchvision.models.detection.FasterRCNN_ResNet50_FPN_Weights.COCO_V1
model = fasterrcnn_resnet50_fpn(weights=weights)

num_classes = 2  # background + cell
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)

# Dataset
annotations_file = 'annotation_frame.csv'
img_dir=''

num_samples = len(pd.read_csv(annotations_file))
crop_size = (256, 256)
transform = transforms.Compose([
    transforms.Resize((crop_size[0], crop_size[1])),
    transforms.ToTensor(),
])

dataset = CustomDatasetClass(annotations_file, img_dir, num_samples, crop_size, transform=transform)

# DataLoader
batch_size = 32
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # 3. Setting up an optimzer, a detection metric and the train and validation dataloaders
#
# To train the object detector, it is necessary to select an appropriate optimizer. Additionally, the torchmetrics class needs to be instantiated before it can be used for evaluation or tracking metrics during training.
# Additionally, initialize a training and validation dataloader your dataset. For more information on how to set up your dataloaders have a look [here](https://pytorch.org/tutorials/beginner/basics/data_tutorial.html)

# %%
import torch.optim as optim
import torchmetrics
from sklearn.model_selection import train_test_split

params = [p for p in model.parameters() if p.requires_grad]
optimizer = optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)

detection_metric = torchmetrics.detection.MeanAveragePrecision()

# split in training and validation sets
train_dataset, val_dataset = train_test_split(dataset, test_size=0.2, random_state=42)

# trainingDataLoader
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# validationDataLoader
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Error loading image at index 2133: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 14926: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 3288: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 7730: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 8852: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 425: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 10277: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 15027: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 16840: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 1890: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 19476: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 8530: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 1282: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 16095: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 13477: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 8542: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 11124: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 10205: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 2714: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 12196: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 14956: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 11953: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 16027: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 14735: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 15951: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 2760: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 17823: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 8299: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 7834: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 16006: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 6325: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 14677: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 3214: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 15886: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 8910: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 1833: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 7886: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 3658: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 14803: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 8037: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 1139: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 1604: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 10186: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 11900: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 16643: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 16995: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 9279: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 10792: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 1692: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 5792: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 12385: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 7068: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 14146: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 18042: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 12023: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 653: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 19372: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 14150: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 12042: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 14545: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 3234: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 18822: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 4605: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 2726: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 3974: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 1113: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 10946: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 18084: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 930: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 5140: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 373: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 2099: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 6735: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 2993: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 9246: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 4693: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 17842: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 2973: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 5478: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 1275: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 14915: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 9172: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 17399: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 7305: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 16582: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 13451: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 17203: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 11255: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 2132: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 19661: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 17104: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 13727: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 17465: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 4309: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 8815: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 41: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 18100: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 10476: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 8304: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 13174: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 5309: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 862: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 6885: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 18683: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 19632: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 11409: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 1720: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 4973: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 4417: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 19413: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 7499: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 5999: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 13959: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 638: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 6415: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 12522: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 8138: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 12898: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 566: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 14813: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 9992: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 17527: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 6286: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 10275: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 12223: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 13702: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 3703: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 14312: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 10999: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 1305: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 5351: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 1219: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 1362: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 10840: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 13632: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 10969: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 18918: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 13059: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 13143: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 14583: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 4894: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 15905: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 12038: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 10760: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 7270: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 19178: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 5081: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 54: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 17459: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 8409: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 15170: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 1795: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 7584: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 7303: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 1964: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 2629: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 17058: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 13881: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 6547: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 17401: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 14950: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 7900: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 8851: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 5883: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 11300: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 6045: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 2543: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 16234: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 17284: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 2275: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 13365: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 12555: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 420: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 284: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 998: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 16825: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 3181: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 4699: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 14723: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 5357: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 3834: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 19364: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 3245: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 13024: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 18079: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 12553: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 15310: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 10810: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 10571: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 14230: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 4373: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 7934: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 17151: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 14957: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 7551: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 682: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 12160: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 10714: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 150: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 19414: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 19356: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 3411: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 7359: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 16096: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 7458: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 14158: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 5144: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 15542: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8654.tiff'
# Error loading image at index 8528: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 9567: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 5836: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 2661: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 17314: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 4388: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 13506: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 3788: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 5107: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 1276: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 15597: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8654.tiff'
# Error loading image at index 14544: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 6887: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 12353: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 116: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 15935: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 11327: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 11239: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 17510: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 1112: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 16192: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 7275: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 18714: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 14912: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 9431: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 3651: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 11607: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 1255: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 3684: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 10436: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 13525: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 18736: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 13339: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 2481: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 7459: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 7277: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 9877: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 17172: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 829: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 12252: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 1602: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 10827: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 3058: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 14356: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 18876: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 19249: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 12848: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 13008: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 8486: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 8826: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 17941: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 13603: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 16727: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 1921: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 16574: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 9260: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 11244: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 12425: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 7168: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 15278: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 3851: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 3938: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 5786: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 5859: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 16334: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 7451: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 14339: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 13967: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 5128: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 3607: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 18612: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 1320: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 18134: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 9329: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 11610: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 168: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 13735: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 9366: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 17899: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 17252: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 12439: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 398: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 5952: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 13972: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 149: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 3069: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 6759: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 94: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 12859: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 14772: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 9975: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# ...
# Error loading image at index 2189: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 2743: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 7506: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 15199: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 2812: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 18734: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 3528: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 17803: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 6590: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 7775: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 14415: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 5183: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 3077: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 1397: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 6433: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 11243: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 6069: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 1006: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 9919: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 8319: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 2238: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 5502: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 4505: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# Error loading image at index 3508: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 5638: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 16025: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 15790: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 8421: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 4836: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 10505: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 7696: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 7472: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 18495: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 2864: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 13017: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 16416: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 447: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 12499: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 7553: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 5601: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2735.tiff'
# Error loading image at index 14222: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 18627: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 3011: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 19527: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 16177: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 14488: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 2008: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 10206: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 12475: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 15759: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8654.tiff'
# Error loading image at index 9683: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 10590: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 16652: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2921.tiff'
# Error loading image at index 10301: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 8658: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 11449: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 7267: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 2085: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2876.tiff'
# Error loading image at index 5282: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0672.tiff'
# Error loading image at index 2698: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8581.tiff'
# Error loading image at index 17791: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 15090: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 14123: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 17330: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0674.tiff'
# Error loading image at index 14935: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2865.tiff'
# Error loading image at index 7020: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 12906: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 3282: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 10219: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2999.tiff'
# Error loading image at index 11358: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 8993: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 3784: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0519.tiff'
# Error loading image at index 1747: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_9845.tiff'
# Error loading image at index 7921: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2751.tiff'
# Error loading image at index 10960: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 13781: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 11621: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 8902: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2862.tiff'
# Error loading image at index 6627: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_8583.tiff'
# Error loading image at index 10904: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 14450: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2685.tiff'
# Error loading image at index 18286: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2852.tiff'
# Error loading image at index 11680: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 6: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 695: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 19500: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0677.tiff'
# Error loading image at index 7671: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0531.tiff'
# Error loading image at index 1347: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2906.tiff'
# Error loading image at index 11147: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 12277: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2864.tiff'
# Error loading image at index 247: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0495.tiff'
# Error loading image at index 12749: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 16261: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 13189: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2783.tiff'
# Error loading image at index 11249: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0561.tiff'
# Error loading image at index 16084: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_2916.tiff'
# Error loading image at index 4352: [Errno 2] No such file or directory: '/Users/alexandervaptsarov/Desktop/Image Understanding/Milestone Three/AgNOR_0620.tiff'
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # 4. Train and validation loop
#
# Please write two functions, one for training and one for evaluating your object detector. The functionality should be very similar to what you had to do for the last milestone. Use these functions to train the detector for a few epochs. During training, track both the training losses and the validation metrics to monitor the performance of the model. Save the best detector as observed by the validation metric.

# %%
def train_one_epoch(model, dataloader, optimizer, device):
    model.train()
    train_loss = 0.0

    for images, targets in dataloader:
        images = [image.to(device) for image in images]
        targets = [{k: v.to(device) for k, v in target.items()} for target in targets]

        optimizer.zero_grad()
        loss_dict = model(images, targets)
        losses = sum(loss for loss in loss_dict.values())
        losses.backward()
        optimizer.step()

        train_loss += losses.item()

    return train_loss / len(dataloader)


def evaluate(model, dataloader, device, metric):
    model.eval()
    metric.reset()

    with torch.no_grad():
        for images, targets in dataloader:
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in target.items()} for target in targets]

            outputs = model(images)
            metric(outputs, targets)

    return metric.compute()


def train_and_validate(model, train_dataloader, val_dataloader, optimizer, device, num_epochs):
    best_metric = 0.0
    best_model = None

    for epoch in range(num_epochs):
        # Training
        train_loss = train_one_epoch(model, train_dataloader, optimizer, device)
        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss:.4f}")

        # Validation
        val_metric = evaluate(model, val_dataloader, device, metric)
        print(f"Epoch [{epoch+1}/{num_epochs}], Validation mAP: {val_metric['mAP'].item():.4f}")

        # Save the best model based on validation metric
        if val_metric['mAP'].item() > best_metric:
            best_metric = val_metric['mAP'].item()
            best_model = model.state_dict()

    return best_model

# %%
device = torch.device('cpu')
# device = torch.device('mps')
model.to(device)
print(device)
# Out:
# cpu

# %%
train_and_evaluate(model, train_dataloader, val_dataloader, optimizer, detection_metric, device, num_epochs=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train_and_evaluate(model, train_dataloader, val_dataloader, optimizer, detection_metric, device, num_epochs=10)
#
# NameError: name 'train_and_evaluate' is not defined
